# %%
import pandas as pd 
import numpy as np

# %%
covid_db = pd.read_csv("C:/Users/rnikk/OneDrive/Desktop/git_projects/covid_19_india.csv" )

# %%
covid_db
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
covid_db.drop("Sno",inplace = True , axis = 1)

# %% [markdown]
# As we can see there is no useful data available in ConfirmedIndianNational,ConfirmedForeignNational and time columns we must drop them in order to make our data look more cleaner

# %%
covid_db.drop(["ConfirmedIndianNational","ConfirmedForeignNational","Time"],inplace = True , axis =1)

# %%
covid_db.head()
# Out:
#          Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0  2020-01-30               Kerala      0       0          1
# 1  2020-01-31               Kerala      0       0          1
# 2  2020-02-01               Kerala      0       0          2
# 3  2020-02-02               Kerala      0       0          3
# 4  2020-02-03               Kerala      0       0          3

# %% [markdown]
# Lets see the total number of Cured, Deaths and Confirmed cases in each state(using group by)

# %%
covid_db.groupby("State/UnionTerritory").sum().sort_values("Confirmed",ascending = False).head()
# Out:
#                            Cured    Deaths   Confirmed
# State/UnionTerritory
# Maharashtra           1018765039  23737432  1121491467
# Karnataka              441844360   6053762   485970693
# Kerala                 420174235   1888177   458906023
# Tamil Nadu             404095807   5916658   431928644
# Andhra Pradesh         370426530   2939367   392432753

# %% [markdown]
# Now, lets the the total number of active cases in each state(using pivot_table fuction)

# %%
covid_db['Active_cases']=covid_db['Confirmed']-(covid_db['Cured']+covid_db['Deaths'])

# %%
covid_db.head()
# Out:
#          Date State/UnionTerritory  Cured  Deaths  Confirmed  Active_cases
# 0  2020-01-30               Kerala      0       0          1             1
# 1  2020-01-31               Kerala      0       0          1             1
# 2  2020-02-01               Kerala      0       0          2             2
# 3  2020-02-02               Kerala      0       0          3             3
# 4  2020-02-03               Kerala      0       0          3             3

# %%
statewise = pd.pivot_table(covid_db, values=["Confirmed","Cured","Deaths","Active_cases"],
                            index = "State/UnionTerritory",aggfunc = max)

# %%
statewise.head()
# Out:
#                              Active_cases  Confirmed    Cured  Deaths
# State/UnionTerritory
# Andaman and Nicobar Islands          1154       7548     7412     129
# Andhra Pradesh                     211554    1985182  1952736   13564
# Arunachal Pradesh                    4465      50605    47821     248
# Assam                               56295     576149   559684    5420
# Bihar                              115152     725279   715352    9646

# %% [markdown]
# lets see the recovery and mortality rates of each state

# %%
statewise['Recovery_rate']=statewise['Cured']*100/statewise['Confirmed']

# %%
statewise['Mortality_rate']=statewise['Deaths']*100/statewise['Confirmed']

# %%
statewise=statewise.sort_values("Confirmed",ascending = False)

# %%
statewise.head()
# Out:
#                       Active_cases  Confirmed    Cured  Deaths  Recovery_rate  \
# State/UnionTerritory
# Maharashtra                 701614    6363442  6159676  134201      96.797865
# Maharashtra***               97932    6229596  6000911  130753      96.329056
# Kerala                      445692    3586693  3396184   18004      94.688450
# Karnataka                   605515    2921049  2861499   36848      97.961349
# Karanataka                   27550    2885238  2821491   36197      97.790581
#
#                       Mortality_rate
# State/UnionTerritory
# Maharashtra                 2.108937
# Maharashtra***              2.098900
# Kerala                      0.501967
# Karnataka                   1.261465
# Karanataka                  1.254559

# %% [markdown]
# These were few useful insights that we have successfully drawn from our dataset using python and its libraries
